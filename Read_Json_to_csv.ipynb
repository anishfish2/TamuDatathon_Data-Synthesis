# %%
#Imports
import json 
import pandas as pd

# %%
#Open Json file
with open('hiring.json', encoding="utf8") as json_file:
    print(json_file.read())
# Out:
# [{"company":"1010data","lastChecked":"31-Mar-2020","logo":"https://i.imgur.com/I5ORa3n.jpg","locations":"New York, NY; Los Angeles, CA","roles":"Software Engineer, Product Manager, Data Scientist, Sales, Data Engineer","link":"https://www.1010data.com/company/careers/open-positions/","comments":"","geos":"40.753622,-73.972841|33.020237,-117.281427"},{"company":"10x Genomics","lastChecked":"10-Apr-2020","logo":"https://logo.clearbit.com/10xgenomics.com","locations":"Pleasanton, CA; San Francisco, CA; Remote","roles":"Software Engineer, Software Engineering Manager, Site Reliability / DevOps, Product Manager","link":"https://10xgenomics.com/pages/full-stack-engineer","comments":"No biology background required!","geos":"37.6943023,-121.9212663|37.791305,-122.3937352"},{"company":"247.ai","lastChecked":"12-Aug-2021","logo":"https://logo.clearbit.com/247.ai","locations":"San Jose, CA; Toronto, Canada; India","roles":"Software Engineer, Software Engineering Manager, Site Reliability / DevO
# ...

# %%
df = pd.read_json('hiring.json')

# %%
df.head()

# %%
df.to_csv("levels_fyi_hiring.csv")
# Out:
#               company  lastChecked  \
# 0            1010data  31-Mar-2020
# 1        10x Genomics  10-Apr-2020
# 2              247.ai  12-Aug-2021
# 3  Abarca Health LLC.  24-Apr-2020
# 4                Ably  05-Apr-2020
#
#                                          logo  \
# 0             https://i.imgur.com/I5ORa3n.jpg
# 1   https://logo.clearbit.com/10xgenomics.com
# 2            https://logo.clearbit.com/247.ai
# 3  https://logo.clearbit.com/abarcahealth.com
# 4          https://logo.clearbit.com/ably.com
#
#                                    locations  \
# 0              New York, NY; Los Angeles, CA
# 1  Pleasanton, CA; San Francisco, CA; Remote
# 2       San Jose, CA; Toronto, Canada; India
# 3                        Remote; Puerto Rico
# 4                 London, EN, United Kingdom
#
#                                                roles  \
# 0  Software Engineer, Product Manager, Data Scien...
# 1  Software Engineer, Software Engineering Manage...
# ...

# %%
df.fillna('NA')

# %%
df.drop('logo', 1)
# Out:
#                 company  lastChecked  \
# 0              1010data  31-Mar-2020
# 1          10x Genomics  10-Apr-2020
# 2                247.ai  12-Aug-2021
# 3    Abarca Health LLC.  24-Apr-2020
# 4                  Ably  05-Apr-2020
# ..                  ...          ...
# 604              Zippin  06-May-2021
# 605        ZipRecruiter  30-Mar-2020
# 606                Zoom  20-Apr-2021
# 607              Zumper  29-May-2020
# 608               Zynga  24-Apr-2020
#
#                                            logo  \
# 0               https://i.imgur.com/I5ORa3n.jpg
# 1     https://logo.clearbit.com/10xgenomics.com
# 2              https://logo.clearbit.com/247.ai
# 3    https://logo.clearbit.com/abarcahealth.com
# 4            https://logo.clearbit.com/ably.com
# ..                                          ...
# 604     https://logo.clearbit.com/getzippin.com
# 605             https://i.imgur.com/jNOYoK0.png
# 606          https://logo.clearbit.com/zoom.com
# ...

# %%
df.to_csv("Cleaned_fyi_hiring.csv")
# Out:
#                 company  lastChecked  \
# 0              1010data  31-Mar-2020
# 1          10x Genomics  10-Apr-2020
# 2                247.ai  12-Aug-2021
# 3    Abarca Health LLC.  24-Apr-2020
# 4                  Ably  05-Apr-2020
# ..                  ...          ...
# 604              Zippin  06-May-2021
# 605        ZipRecruiter  30-Mar-2020
# 606                Zoom  20-Apr-2021
# 607              Zumper  29-May-2020
# 608               Zynga  24-Apr-2020
#
#                                              locations  \
# 0                        New York, NY; Los Angeles, CA
# 1            Pleasanton, CA; San Francisco, CA; Remote
# 2                 San Jose, CA; Toronto, Canada; India
# 3                                  Remote; Puerto Rico
# 4                           London, EN, United Kingdom
# ..                                                 ...
# 604  San Francisco, CA; Dallas, TX; Toronto, ON; Re...
# 605                       Tel Aviv, Israel; London, UK
# ...
